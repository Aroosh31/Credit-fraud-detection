# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
import tqdm
from imblearn.datasets import make_imbalance
from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv(r"C:\Users\Arush\Downloads\creditcard.csv (1)\creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# # Data is PCA transformated
# # data is imbalanced

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.iloc[:,30]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.918649e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.682686e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.761736e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.811118e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552103e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.040130e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.698953e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.893285e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.147640e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.772925e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.289524e-16      1.020713   -4.797473     -0.762494
# ...

# %%
df['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
df.isna().sum().sort_values()
# Out:
# Time      0
# V28       0
# V27       0
# V26       0
# V25       0
# V24       0
# V23       0
# V22       0
# V21       0
# V20       0
# V19       0
# V18       0
# V17       0
# V16       0
# Amount    0
# V15       0
# V13       0
# V12       0
# V11       0
# V10       0
# V9        0
# V8        0
# V7        0
# V6        0
# V5        0
# V4        0
# V3        0
# V2        0
# V1        0
# V14       0
# Class     0
# dtype: int64

# %%
# duplicate check
df.duplicated().sum()
# Out:
# 1081

# %%
df.drop_duplicates(inplace=True)

# %%
sns.distplot(df['Amount'])
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier , AdaBoostClassifier ,GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import classification_report, confusion_matrix ,f1_score ,precision_score ,recall_score ,accuracy_score

# %%
def train_eval(models):
    x = df.drop('Class',axis=1).copy()
    y = df['Class'].copy()
    
    # Balance Data
    x , y = make_imbalance(x,y, sampling_strategy={0: 470, 1: 470},random_state=14)
    
    # Split Data
    x_train ,x_test ,y_train ,y_test = train_test_split(x,y,test_size=.3,random_state=42)
    acc  = []
    for model in models:
        model.fit( x_train , y_train )
        y_h    = model.predict(x_test)
        f1     = f1_score(y_test,y_h)
        prs    = precision_score(y_test,y_h)
        rec    = recall_score(y_test,y_h)
        acc_sc = accuracy_score(y_test,y_h)
        acc.append([model,acc_sc,f1,prs,rec])
    return acc

# %% [markdown]
# # model instances

# %%
# models Instances
lr  = LogisticRegression(random_state=42)
knn = KNeighborsClassifier()
rf  = RandomForestClassifier(random_state=42)
svm = SVC(random_state=42)
ada = AdaBoostClassifier(random_state=42)
nav = GaussianNB()
GRD = GradientBoostingClassifier(random_state=42)
dt  = DecisionTreeClassifier(random_state=42)

# List of models
models = [lr,knn,rf,svm,ada,nav,GRD,dt]

# Train Test Models 
acc = train_eval(models)
pd.DataFrame(acc,columns=['name','acc','f1','precision','recall'])
# Out:
#                                                 name       acc        f1  \
# 0                LogisticRegression(random_state=42)  0.904255  0.900369
# 1                             KNeighborsClassifier()  0.638298  0.640845
# 2  (DecisionTreeClassifier(max_features='sqrt', r...  0.939716  0.936330
# 3                               SVC(random_state=42)  0.514184  0.486891
# 4  (DecisionTreeClassifier(max_depth=1, random_st...  0.918440  0.915751
# 5                                       GaussianNB()  0.851064  0.826446
# 6  ([DecisionTreeRegressor(criterion='friedman_ms...  0.939716  0.937269
# 7            DecisionTreeClassifier(random_state=42)  0.890071  0.887273
#
#    precision    recall
# 0   0.917293  0.884058
# 1   0.623288  0.659420
# 2   0.968992  0.905797
# 3   0.503876  0.471014
# 4   0.925926  0.905797
# 5   0.961538  0.724638
# 6   0.954887  0.920290
# 7   0.890511  0.884058

# %%
x = df.drop('Class',axis=1).copy()
y = df['Class'].copy()
x , y = make_imbalance(x,y, sampling_strategy={0: 470, 1: 470},random_state=14)
x_train ,x_test ,y_train ,y_test = train_test_split(x,y,test_size=.3,random_state=42)
model  = GradientBoostingClassifier(random_state=42)
model.fit(x_train,y_train)
y_h  = model.predict(x_test)
print(classification_report(y_test,y_h))
print(f1_score(y_test,y_h))
print(confusion_matrix(y_test,y_h))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       144
#            1       0.95      0.92      0.94       138
#
#     accuracy                           0.94       282
#    macro avg       0.94      0.94      0.94       282
# weighted avg       0.94      0.94      0.94       282
#
# 0.937269372693727
# [[138   6]
#  [ 11 127]]
